# %% [markdown]
# # My try

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')

# %%
print('train info:')
print(train.info())
print('\ntest info:')
print(test.info())
# Out:
# train info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None
#
# test info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# ...

# %%
print(train.isnull().sum())
print(test.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 不能单纯的合并 full = [train,test] 这样只会是一个list
# full_data = pd.concat([train,test])
full_data = [train,test]

# %%
for data in full_data:
    data['Title'] = data['Name'].str.extract('([A-Za-z]+)\.',expand=False)
# full_data['Title'] = full_data['Name'].str.extract('([A-Za-z]+)\.',expand=False)

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# ...

# %%
sns.countplot('Title',data=train)
plt.gcf().set_size_inches(18,8)
plt.show()

# %%
pd.crosstab(train['Title'],train['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
for data in full_data:
    data['Title'].replace(['Lady', 'Countess','Capt', 'Col',\
 	'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'],'Other',inplace=True)
    data['Title'].replace(['Mlle','Ms'],'Miss',inplace=True)
    data['Title'].replace('Mme','Mrs',inplace=True)

# %%
sns.countplot('Title',data=train)
plt.show()

# %%
for data in full_data:
    data['Family_size'] = data['SibSp'] + data['Parch']
#     data['Is_alone'] = 1 if data['Family_size'] == 0 else 0
sns.countplot('Family_size',data=train)
plt.show()

# %%
print(train.info())
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# Title          891 non-null object
# Family_size    891 non-null int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.5+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# ...

# %%
for data in full_data:
    data['Is_Alone'] = 0
    data.loc[data['Family_size']==0,'Is_Alone'] = 1
pd.crosstab(train['Family_size'],train['Survived'])
# Out:
# Survived       0    1
# Family_size
# 0            374  163
# 1             72   89
# 2             43   59
# 3              8   21
# 4             12    3
# 5             19    3
# 6              8    4
# 7              6    0
# 10             7    0

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_size  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr            1
# 1      0          PC 17599  71.2833   C85        C   Mrs            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss            0
# ...

# %%
test.groupby('Title')['Age'].mean()
# Out:
# Title
# Master     7.406471
# Miss      21.774844
# Mr        32.000000
# Mrs       38.903226
# Other     43.833333
# Name: Age, dtype: float64

# %%
train.groupby('Title')['Age'].mean()
# Out:
# Title
# Master     4.574167
# Miss      21.845638
# Mr        32.368090
# Mrs       35.788991
# Other     45.545455
# Name: Age, dtype: float64

# %%
for data in full_data:
    data.loc[(data['Age'].isnull()&(data['Title']=='Master')),'Age'] = 6
    data.loc[(data['Age'].isnull()&(data['Title']=='Miss')),'Age'] = 22    
    data.loc[(data['Age'].isnull()&(data['Title']=='Mr')),'Age'] = 32    
    data.loc[(data['Age'].isnull()&(data['Title']=='Mrs')),'Age'] = 37    
    data.loc[(data['Age'].isnull()&(data['Title']=='Other')),'Age'] = 45

# %%
train['Age_range'] = pd.qcut(train['Age'],5)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_size  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr            1
# 1      0          PC 17599  71.2833   C85        C   Mrs            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss            0
# ...

# %%
sns.countplot('Age_range',hue='Survived',data=train)
plt.show()

# %%
for data in full_data:
    data.loc[(data['Age']<=20),'Age']=0
    data.loc[(data['Age']>20) & (data['Age']<=26),'Age']=1
    data.loc[(data['Age']>26) & (data['Age']<=32),'Age']=2
    data.loc[(data['Age']>32) & (data['Age']<=38),'Age']=3
    data.loc[(data['Age']>=38),'Age']=4
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  1.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3.0      1
# 2                             Heikkinen, Miss. Laina  female  1.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  3.0      1
# 4                           Allen, Mr. William Henry    male  3.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_size  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr            1
# 1      0          PC 17599  71.2833   C85        C   Mrs            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss            0
# ...

# %%
train = train.drop('Age_range',axis=1)

# %%
train['Age'].value_counts()
# Out:
# 2.0    246
# 0.0    183
# 4.0    178
# 1.0    176
# 3.0    108
# Name: Age, dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
for data in full_data:
    data.loc[data['Embarked'].isnull(),'Embarked']='S'

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Title            0
# Family_size      0
# Is_Alone         0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Title            0
# Family_size      0
# Is_Alone         0
# dtype: int64

# %%
test.loc[test['Fare'].isnull(),'Fare']=test['Fare'].median()

# %%
for data in full_data:
    data['Has_Cabin']=0
    data.loc[data['Cabin'].isnull(),'Has_Cabin']=1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  1.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3.0      1
# 2                             Heikkinen, Miss. Laina  female  1.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  3.0      1
# 4                           Allen, Mr. William Henry    male  3.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_size  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr            1
# 1      0          PC 17599  71.2833   C85        C   Mrs            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss            0
# ...

# %%
for data in full_data:
    data = data.drop(['Name','SibSp','Parch','Ticket','Cabin'],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  1.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  3.0      1
# 2                             Heikkinen, Miss. Laina  female  1.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  3.0      1
# 4                           Allen, Mr. William Henry    male  3.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Family_size  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr            1
# 1      0          PC 17599  71.2833   C85        C   Mrs            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss            0
# ...

# %%
train['Fare'] = pd.qcut(train['Fare'],5,labels=[0,1,2,3,4])

# %%
train = train.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin'],axis=1)
test = test.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin'],axis=1)

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
for data in full_data:
    data['Sex'] = data['Sex'].map({'male':1,'female':0})
    data['Title'] = data['Title'].map({'Mr':0,'Miss':1,'Mrs':2,'Mster':3,'Other':4})
    data['Embarked'] = data['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
train.head()
# Out:
#    Survived  Pclass     Sex  Age Fare Embarked Title  Family_size  Is_Alone
# 0         0       3    male  1.0    0        S    Mr            1         0
# 1         1       1  female  3.0    4        C   Mrs            1         0
# 2         1       3  female  1.0    1        S  Miss            0         1
# 3         1       1  female  3.0    4        S   Mrs            1         0
# 4         0       3    male  3.0    1        S    Mr            0         1

# %%
test.head()
# Out:
#    Pclass     Sex  Age     Fare Embarked Title  Family_size  Is_Alone  \
# 0       3    male  3.0   7.8292        Q    Mr            0         1
# 1       3  female  4.0   7.0000        S   Mrs            1         0
# 2       2    male  4.0   9.6875        Q    Mr            0         1
# 3       3    male  2.0   8.6625        S    Mr            0         1
# 4       3  female  1.0  12.2875        S   Mrs            2         0
#
#    Has_Cabin
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
def map_int(data_frame):
    for data in data_frame:
        data['Sex'] = data['Sex'].map({'male':1,'female':0})
        data['Title'] = data['Title'].map({'Mr':0,'Miss':1,'Mrs':2,'Mster':3,'Other':4})
        data['Embarked'] = data['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
map_int(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-d86a7b7f48ad> in <module>()
# ----> 1 map_int(test)
#
# <ipython-input-39-1c612bf0939a> in map_int(data_frame)
#       1 def map_int(data_frame):
#       2     for data in data_frame:
# ----> 3         data['Sex'] = data['Sex'].map({'male':1,'female':0})
#       4         data['Title'] = data['Title'].map({'Mr':0,'Miss':1,'Mrs':2,'Mster':3,'Other':4})
#       5         data['Embarked'] = data['Embarked'].map({'S':0,'C':1,'Q':2})
#
# TypeError: string indices must be integers, not str

# %%
len(full_data)
# Out:
# 2
