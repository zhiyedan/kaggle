# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# inline表示将图表嵌入到Notebook中
# %matplotlib inline

# %%
train_data = pd.read_csv('../titanic/data/train.csv')
test_data = pd.read_csv('../titanic/data/test.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test_data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
train_data.isnull().sum() # try to fix
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train_data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=train_data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Analysing the features

# %% [markdown]
# ### sex

# %%
train_data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,9))
#train_data[['Sex','Survived']].groupby(['Sex']).mean().plot().bar(ax = ax[0])
train_data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs sex')
sns.countplot('Sex',hue='Survived',data=train_data,ax=ax[1])
ax[1].set_title('Survived vs sex')
plt.show()

# %% [markdown]
# ## Pclass

# %%
# pd.crosstab(train_data.Pclass,train_data.Survived,margins=True).style.background_gradient(cmap='summer_r')
pd.crosstab(train_data.Pclass,train_data.Survived,margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
f,ax=plt.subplots(1,2,figsize=(18,9))
train_data['Pclass'].value_counts().plot.bar(ax=ax[0])
sns.countplot('Pclass',hue='Survived',data=train_data,ax=ax[1])
plt.show()

# %%
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass)
# Out:
# Pclass            1   2    3
# Sex    Survived
# female 0          3   6   72
#        1         91  70   72
# male   0         77  91  300
#        1         45  17   47

# %%
sns.barplot('Pclass','Survived',hue='Sex',data=train_data)
plt.show()

# %% [markdown]
# ##Age

# %%
f,ax = plt.subplots(1,2,figsize=(18,9))
sns.violinplot('Pclass','Age',hue='Survived',data=train_data,split=True,ax=ax[0])
ax[0].set_yticks(range(0,100,10))
sns.violinplot('Sex','Age',hue='Survived',data=train_data,split=True,ax=ax[1])
ax[1].set_yticks(range(0,100,10))
plt.show()

# %%
train_data['Initial'] = 0
for data in train_data:
    train_data['Initial'] = train_data.Name.str.extract('([A-Za-z]+)\.')
# Out:
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
pd.crosstab(train_data.Sex,train_data.Initial)
# Out:
# Initial  Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Sex
# female      0    0         1    0   1         0     1      0       0   182
# male        1    2         0    1   6         1     0      2      40     0
#
# Initial  Mlle  Mme   Mr  Mrs  Ms  Rev  Sir
# Sex
# female      2    1    0  125   1    0    0
# male        0    0  517    0   0    6    1

# %%
train_data.replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull())&(train_data.Initial=='Other'),'Age']=46

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
f,ax = plt.subplots(1,2,figsize=(18,9))
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[0],edgecolor='black',bins=20)
ax[0].set_title('Survived')
ax[0].set_xticks(list(range(0,90,5)))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[1],edgecolor='black',bins=50)
ax[1].set_title('unsurvived')
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=train_data)
plt.show()

# %% [markdown]
# ### Embarked

# %%
pd.crosstab([train_data.Embarked,train_data.Pclass],[train_data.Sex,train_data.Survived],margins=True)
# Out:
# Sex             female      male       All
# Survived             0    1    0    1
# Embarked Pclass
# C        1           1   42   25   17   85
#          2           0    7    8    2   17
#          3           8   15   33   10   66
# Q        1           0    1    1    0    2
#          2           0    2    1    0    3
#          3           9   24   36    3   72
# S        1           2   46   51   28  127
#          2           6   61   82   15  164
#          3          55   33  231   34  353
# All                 81  231  468  109  889

# %%
sns.factorplot('Embarked','Survived',data=train_data)
plt.show()

# %%
f,ax = plt.subplots(2,2,figsize=(19,14))
sns.countplot('Embarked',data=train_data,ax=ax[0,0])
sns.countplot('Embarked',hue='Sex',data=train_data,ax=ax[0,1])
sns.countplot('Embarked',hue='Survived',data=train_data,ax=ax[1,0])
sns.countplot('Embarked',hue='Pclass',data=train_data,ax=ax[1,1])
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=train_data)
plt.show()

# %% [markdown]
# ### Filling Embarked NaN
#
# As we saw that maximum passengers boarded from Port S, we replace NaN with S.

# %%
train_data['Embarked'].fillna('S',inplace=True)

# %%
train_data['Embarked'].isnull().any()
# Out:
# False

# %% [markdown]
# ### SibSip

# %%
pd.crosstab(train_data.SibSp,[train_data.Pclass,train_data.Survived])
# Out:
# Pclass     1       2        3
# Survived   0   1   0   1    0   1
# SibSp
# 0         60  77  70  50  268  83
# 1         18  53  23  32   56  27
# 2          1   4   4   4   10   5
# 3          1   2   0   1   11   1
# 4          0   0   0   0   15   3
# 5          0   0   0   0    5   0
# 8          0   0   0   0    7   0

# %%
sns.factorplot('SibSp','Survived',hue='Pclass',data=train_data)
plt.show()

# %% [markdown]
# ### Parch

# %%
pd.crosstab(train_data.Parch,[train_data.Pclass,train_data.Survived])
# Out:
# Pclass     1       2        3
# Survived   0   1   0   1    0   1
# Parch
# 0         64  99  86  48  295  86
# 1         10  21   8  24   35  20
# 2          5  16   3  13   32  11
# 3          0   0   0   2    2   1
# 4          1   0   0   0    3   0
# 5          0   0   0   0    4   1
# 6          0   0   0   0    1   0

# %%
sns.factorplot('Parch','Survived',hue='Pclass',data=train_data)
plt.show()

# %% [markdown]
# ### Fare

# %%
f,ax = plt.subplots(1,3,figsize=(20,8))
sns.distplot(train_data[train_data['Pclass']==1].Fare,ax=ax[0])
sns.distplot(train_data[train_data['Pclass']==2].Fare,ax=ax[1])
sns.distplot(train_data[train_data['Pclass']==3].Fare,ax=ax[2])
plt.show()

# %% [markdown]
# ### 查看相关性

# %%
sns.heatmap(train_data.corr(),annot=True)
plt.gcf().set_size_inches(10,8)
# plt.show()

# %% [markdown]
# ## Part2:Feature Engineering And Data Cleaning

# %% [markdown]
# ### Age: continous values into categorical values by either Binning or Normalisation.

# %%
train_data['Age_band']=0
train_data.loc[train_data['Age']<=16,'Age_band']=0
train_data.loc[(train_data['Age']>16)&(train_data['Age']<=32),'Age_band']=1
train_data.loc[(train_data['Age']>32)&(train_data['Age']<=48),'Age_band']=2
train_data.loc[(train_data['Age']>48)&(train_data['Age']<=64),'Age_band']=3
train_data.loc[train_data['Age']>64,'Age_band']=4
train_data['Age_band'].value_counts()
# Out:
# 1    382
# 2    325
# 0    104
# 3     69
# 4     11
# Name: Age_band, dtype: int64

# %%
sns.factorplot('Age_band','Survived',col='Pclass',data=train_data)
plt.show()

# %% [markdown]
# ### 家庭人数

# %%
train_data['Family_size']=0
train_data['Alone']=0
train_data['Family_size'] = train_data['SibSp']+train_data['Parch']
train_data.loc[train_data.Family_size==0,'Alone'] = 1
f,ax = plt.subplots(1,2,figsize=(20,8))
sns.factorplot('Family_size','Survived',data=train_data,ax=ax[0])
sns.factorplot('Alone','Survived',data=train_data,ax=ax[1])
plt.show()

# %%
sns.factorplot('Alone','Survived',hue='Sex',col='Pclass',data=train_data)
plt.show()

# %% [markdown]
# ### 船票也需要分段

# %%
train_data['Fare_range']=pd.qcut(train_data['Fare'],4)
train_data['Fare_range'].head()
# Out:
# 0     (-0.001, 7.91]
# 1    (31.0, 512.329]
# 2     (7.91, 14.454]
# 3    (31.0, 512.329]
# 4     (7.91, 14.454]
# Name: Fare_range, dtype: category
# Categories (4, interval[float64]): [(-0.001, 7.91] < (7.91, 14.454] < (14.454, 31.0] < (31.0, 512.329]]

# %%
train_data.groupby(['Fare_range'])['Survived'].mean()
# Out:
# Fare_range
# (-0.001, 7.91]     0.197309
# (7.91, 14.454]     0.303571
# (14.454, 31.0]     0.454955
# (31.0, 512.329]    0.581081
# Name: Survived, dtype: float64

# %%
train_data['Fare_cat']=0
train_data.loc[train_data['Fare']<=7.91,'Fare_cat']=0
train_data.loc[(train_data['Fare']>7.91)&(train_data['Fare']<=14.454),'Fare_cat']=1
train_data.loc[(train_data['Fare']>14.454)&(train_data['Fare']<=31),'Fare_cat']=2
train_data.loc[(train_data['Fare']>31)&(train_data['Fare']<=513),'Fare_cat']=3

# %%
sns.factorplot('Fare_cat','Survived',hue='Sex',data=train_data)
plt.show()

# %%
train_data['Sex'].replace(['male','female'],[0,1],inplace=True)
train_data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
train_data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %% [markdown]
# ### drop useless features

# %%
train_data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_range','PassengerId'],axis=1,inplace=True)

# %%
sns.heatmap(train_data.corr(),annot=True,cmap='RdYlGn')
plt.gcf().set_size_inches(18,15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ## Part3 : predictive modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
data1,data2 = train_test_split(train_data,test_size=0.3,random_state=0,stratify=train_data['Survived'])
data1_X = data1[data1.columns[1:]]
data1_Y = data1[data1.columns[:1]]
data2_X = data2[data2.columns[1:]]
data2_Y = data2[data2.columns[:1]]
X = train_data[train_data.columns[1:]]
Y = train_data['Survived']

# %%
model = svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(data1_X,data1_Y)
prediction1 = model.predict(data2_X)
print('Accuracy of the svm is :',metrics.accuracy_score(prediction1,data2_Y))
# Out:
# ('Accuracy of the svm is :', 0.83582089552238803)
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
model = LogisticRegression()
model.fit(data1_X,data1_Y)
prediction2 = model.predict(data2_X)
print('Accuracy of the logistic regression is:',metrics.accuracy_score(prediction2,data2_Y))
# Out:
# ('Accuracy of the logistic regression is:', 0.81716417910447758)

# %%
model = DecisionTreeClassifier()
model.fit(data1_X,data1_Y)
prediction3 = model.predict(data2_X)
print('Accuracy of the decision tree is:',metrics.accuracy_score(prediction3,data2_Y))
# Out:
# ('Accuracy of the decision tree is:', 0.80970149253731338)

# %%
model = KNeighborsClassifier()
model.fit(data1_X,data1_Y)
prediction4 = model.predict(data2_X)
print('Accuracy of the KNN is:',metrics.accuracy_score(prediction4,data2_Y))
# Out:
# ('Accuracy of the KNN is:', 0.83208955223880599)
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
model = LogisticRegression()
model.fit(data1_X,data1_Y)
prediction2 = model.predict(data2_X)
print('Accuracy of the logistic regression is:',metrics.accuracy_score(prediction2,data2_Y))
# Out:
# ('Accuracy of the logistic regression is:', 0.81716417910447758)

# %%
a_index = list(range(1,11))
a = pd.Series()
for i in list(range(1,11)):
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(data1_X,data1_Y)
    prediction = model.predict(data2_X)
    a = a.append(pd.Series(metrics.accuracy_score(prediction,data2_Y)))
plt.plot(a_index,a)
# Out:
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """

# %%
model = GaussianNB()
model.fit(data1_X,data1_Y)
prediction5 = model.predict(data2_X)
print('The accuracy of the gaussian naive nayes classifier is:',metrics.accuracy_score(prediction5,data2_Y))
# Out:
# ('The accuracy of the gaussian naive nayes classifier is:', 0.81343283582089554)

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(data1_X,data1_Y)
prediction6 = model.predict(data2_X)
print('The accuracy of the gaussian naive nayes classifier is:',metrics.accuracy_score(prediction6,data2_Y))
# Out:
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ('The accuracy of the gaussian naive nayes classifier is:', 0.81716417910447758)

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
kfold = KFold(n_splits=10,random_state=10)
mean = []
std = []
accuracy = []
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree','Naive Bayes','Random Forest']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),KNeighborsClassifier(n_neighbors=9),DecisionTreeClassifier(),GaussianNB(),RandomForestClassifier(n_estimators=100)]
for model in models:
    cv_result = cross_val_score(model,X,Y,cv=kfold,scoring='accuracy')
    mean.append(cv_result.mean())
    std.append(cv_result.std())
    accuracy.append(cv_result)
new_models_dataframe2 = pd.DataFrame({'CV mean':mean, 'Std':std}, index=classifiers)
new_models_dataframe2
# Out:
#                       CV mean       Std
# Linear Svm           0.793471  0.047797
# Radial Svm           0.828290  0.034427
# Logistic Regression  0.805843  0.021861
# KNN                  0.813783  0.041210
# Decision Tree        0.808115  0.028790
# Naive Bayes          0.801386  0.028999
# Random Forest        0.812622  0.033735

# %%
plt.subplots(figsize=(12,6))
box = pd.DataFrame(accuracy,index=classifiers)
box.T.boxplot()

# %% [markdown]
# ## Confusion Matrix

# %%
f,ax = plt.subplots(2,3,figsize=(18,10))
pred = cross_val_predict(svm.SVC(kernel='rbf'),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[0,0],annot=True,fmt='2.0f')
ax[0,0].set_title('SVM with rbf kernel')

pred = cross_val_predict(KNeighborsClassifier(n_neighbors=9),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[0,1],annot=True,fmt='2.0f')
ax[0,1].set_title('KNN neighbors is 9')

pred = cross_val_predict(RandomForestClassifier(n_estimators=100),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[0,2],annot=True,fmt='2.0f')
ax[0,2].set_title('Random forest with estimators=100')

pred = cross_val_predict(LogisticRegression(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[1,0],annot=True,fmt='2.0f')
ax[1,0].set_title('Logistic regression')

pred = cross_val_predict(DecisionTreeClassifier(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[1,1],annot=True,fmt='2.0f')
ax[1,1].set_title('Decision tree')

pred = cross_val_predict(GaussianNB(),X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,pred),ax=ax[1,2],annot=True,fmt='2.0f')
ax[1,2].set_title('Naive bayes')
plt.subplots_adjust(hspace=0.2,wspace=0.2)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### Hyper param selection

# %%
from sklearn.model_selection import GridSearchCV
gamma = map(lambda x:x/10.0,range(1,11))
# 这里使用copy 而不是单纯的改变指针，c=gamma
C = gamma[:]
C.insert(0,0.05)
kernel = ['rbf','linear']
hyper = {'kernel':kernel,'C':C,'gamma':gamma}
gd = GridSearchCV(estimator=svm.SVC(),param_grid=hyper,verbose=True)
gd.fit(X,Y)
print('best_score is :',gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 3 folds for each of 220 candidates, totalling 660 fits
# ('best_score is :', 0.82828282828282829)
# SVC(C=0.5, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# [Parallel(n_jobs=1)]: Done 660 out of 660 | elapsed:   16.5s finished

# %%
n_estimators= range(100,1000,100)
hyper = {'n_estimators':n_estimators}
gd = GridSearchCV(estimator=RandomForestClassifier(),param_grid=hyper,verbose=True)
gd.fit(X,Y)
print(gd.best_score_)
print(gd.best_estimator_)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.2min finished
# 0.817059483726
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=400, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# ## Ensembling

# %% [markdown]
# ### voting classifier

# %%
from sklearn.ensemble import VotingClassifier
estimators = [('KNN',KNeighborsClassifier()),
              ('RBF',svm.SVC(probability=True,kernel='rbf',C=0.5,gamma=0.1)),
              ('Rfor',RandomForestClassifier(n_estimators=500,random_state=0)),
             ('LR',LogisticRegression(C=0.05)),
             ('DT',DecisionTreeClassifier(random_state=0)),
             ('NB',GaussianNB())]
ensemble_lin_rbf = VotingClassifier(estimators=estimators,voting='soft').fit(data1_X,data1_Y)
print('the accuracy for ensembled model is :',ensemble_lin_rbf.score(data2_X,data2_Y))
cross = cross_val_score(ensemble_lin_rbf,X,Y,cv=10,scoring='accuracy')
print('teh cross validated score is:',cross.mean())
# Out:
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:112: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/label.py:147: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ('the accuracy for ensembled model is :', 0.82089552238805974)
# ('teh cross validated score is:', 0.81592498013846326)

# %% [markdown]
# ### bagged KNN

# %%
from sklearn.ensemble import BaggingClassifier
model = BaggingClassifier(base_estimator=KNeighborsClassifier(n_neighbors=3),random_state=0,n_estimators=700)
model.fit(data1_X,data1_Y)
prediction = model.predict(data2_X)
print('accuracy for bagging knn is :',metrics.accuracy_score(prediction,data2_Y))
result = cross_val_score(model,X,Y,cv=10,scoring='accuracy')
print('the cross validated score for bagged KNN is :',result.mean())
result
# Out:
# ('accuracy for bagging knn is :', 0.83582089552238803)
# ('the cross validated score for bagged KNN is :', 0.81488934286687087)
# array([ 0.72222222,  0.84444444,  0.73033708,  0.83146067,  0.83146067,
#         0.87640449,  0.85393258,  0.7752809 ,  0.86516854,  0.81818182])

# %%
model = BaggingClassifier(base_estimator=RandomForestClassifier(),random_state=0,n_estimators=100)
model.fit(data1_X,data1_Y)
prediction = model.predict(data2_X)
print('the accuracy for bagging random forest classifier is:',metrics.accuracy_score(prediction,data2_Y))
result = cross_val_score(model,X,Y,cv=10,scoring='accuracy')
print('the cv score is :',result.mean())
result
# Out:
# ('the accuracy for bagging random forest classifier is:', 0.81716417910447758)
# ('the cv score is :', 0.81824792872545671)
# array([ 0.75555556,  0.83333333,  0.75280899,  0.85393258,  0.85393258,
#         0.83146067,  0.84269663,  0.75280899,  0.87640449,  0.82954545])

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators=100,random_state=0,learning_rate=0.05)
result = cross_val_score(ada,X,Y,cv=10,scoring='accuracy')
print(result.mean())
result
# Out:
# 0.815887526955
# array([ 0.83333333,  0.82222222,  0.7752809 ,  0.86516854,  0.83146067,
#         0.79775281,  0.82022472,  0.78651685,  0.83146067,  0.79545455])

# %%
import xgboost
model = xgboost.XGBClassifier(n_estimators=699,learning_rate=0.1)
result=cross_val_score(model,X,Y,cv=10,scoring='accuracy')
print(result.mean())
result
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-108-2d53ddf154fc> in <module>()
# ----> 1 import xgboost
#       2 model = xgboost.XGBClassifier(n_estimators=699,learning_rate=0.1)
#       3 result=cross_val_score(model,X,Y,cv=10,scoring='accuracy')
#       4 print(result.mean())
#       5 result
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/__init__.py in <module>()
#       9 import os
#      10
# ---> 11 from .core import DMatrix, Booster
#      12 from .training import train, cv
#      13 from . import rabit                   # noqa
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/core.py in <module>()
#     110
#     111 # load the XGBoost library globally
# --> 112 _LIB = _load_lib()
#     113
#     114
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/core.py in _load_lib()
# ...

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-118-afdaff4619ce> in <module>()
# ----> 1 import xgboost
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/__init__.py in <module>()
#       9 import os
#      10
# ---> 11 from .core import DMatrix, Booster
#      12 from .training import train, cv
#      13 from . import rabit                   # noqa
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/core.py in <module>()
#     110
#     111 # load the XGBoost library globally
# --> 112 _LIB = _load_lib()
#     113
#     114
#
# /home/zhiyedan/anaconda2/lib/python2.7/site-packages/xgboost/core.py in _load_lib()
#     104     if len(lib_path) == 0:
#     105         return None
# --> 106     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     107     lib.XGBGetLastError.restype = ctypes.c_char_p
#     108     return lib
#
# ...

# %%
ada = AdaBoostClassifier(n_estimators=200,random_state=0,learning_rate=0.05)
result = cross_val_predict(ada,X,Y,cv=10)
sns.heatmap(confusion_matrix(Y,result),annot=True,fmt='2.0f')
plt.show()

# %% [markdown]
# ### feature importance

# %%
f,ax = plt.subplots(1,2,figsize=(18,10))
model = RandomForestClassifier(n_estimators=500,random_state=0)
model.fit(X,Y)
pd.Series(model.feature_importances_,X.columns).sort_values(ascending=True).plot.barh(ax=ax[0])

model = AdaBoostClassifier(n_estimators=200,learning_rate=0.05,random_state=0)
model.fit(X,Y)
pd.Series(model.feature_importances_, X.columns).sort_values(ascending=True).plot.barh(ax=ax[1])

plt.show()
